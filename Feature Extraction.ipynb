# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('train.csv/train.csv')

# %%
dataframe.dropna()
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# 5            5      11      12
# 6            6      13      14
# 7            7      15      16
# 8            8      17      18
# 9            9      19      20
# 10          10      21      22
# 11          11      23      24
# 12          12      25      26
# 13          13      27      28
# 14          14      29      30
# 15          15      31      32
# 16          16      33      34
# 17          17      35      36
# 18          18      37      38
# 19          19      39      40
# 20          20      41      42
# 21          21      43      44
# 22          22      45      46
# 23          23      47      48
# 24          24      49      50
# 25          25      51      52
# 26          26      53      54
# 27          27      55      56
# 28          28      57      58
# ...

# %%
#Extracting the frequency of qid1

dataframe['freq_qid1'] = dataframe.groupby(['qid1'])['qid1'].transform('count')

# %%
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3

# %%
#Extracting the frequency of qid2

dataframe['freq_qid2'] = dataframe.groupby(['qid2'])['qid2'].transform('count')
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2
# 0          1
# 1          1
# 2          1
# 3          1
# ...

# %%
#Extrcting the length of question1

dataframe['ques1len'] = dataframe['question1'].str.len()
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len
# 0          1        66
# 1          1        51
# ...

# %%
#Extrcting the length of question2

dataframe['ques2len'] = dataframe['question2'].str.len()
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len
# 0          1        66      57.0
# ...

# %%
#Extracting the number of words in question1

dataframe['ques1_num_words'] = dataframe['question1'].apply(lambda row: len(row.split(" ")))
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words
# ...

# %%
#Extracting the number of words in question2

dataframe['ques2_num_words'] = dataframe['question2'].apply(lambda row: len(str(row).split(" ")))
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words
# ...

# %%
#Extracting the common words in question1 and question2

dataframe['common_words'] = [set(x[3].split()) & set(str(x[4]).split()) for x in dataframe.values]
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words  \
# ...

# %%
#Extracting the number of common words in question1 and question2

dataframe['n_common_words'] = dataframe['common_words'].str.len()
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words  \
# ...

# %%
#Extracting the total number of words in question1 and question2

dataframe['word_total'] = dataframe['ques1_num_words'] + dataframe['ques2_num_words']
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words  \
# ...

# %%
# word_share = common_words/word_total

dataframe['word_share'] = dataframe['n_common_words']/dataframe['word_total']
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words  \
# ...

# %%
#Sum total of frequency of question1 and question2

dataframe['freq_qid1+freq_qid2'] = dataframe['freq_qid1']+dataframe['freq_qid2']
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words  \
# ...

# %%
#absolute difference of frequency of question1 and question2

dataframe['freq_qid1-freq_qid2'] = dataframe['freq_qid1']-dataframe['freq_qid2']
dataframe.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  freq_qid1  \
# 0  What is the step by step guide to invest in sh...             0          1
# 1  What would happen if the Indian government sto...             0          4
# 2  How can Internet speed be increased by hacking...             0          1
# 3  Find the remainder when [math]23^{24}[/math] i...             0          1
# 4            Which fish would survive in salt water?             0          3
#
#    freq_qid2  ques1len  ques2len  ques1_num_words  ques2_num_words  \
# ...

# %% [markdown]
# ## Analysing the features

# %% [markdown]
# ### word_share

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.FacetGrid(dataframe, hue="is_duplicate", height=5)
g=g.map(sns.distplot, "word_share").add_legend();
g.axes[0,0].set_xlabel('word_share')
plt.title('word_share Histogram')
plt.show();

# %% [markdown]
# From the above plot, we can confirm that word_share is a significantly useful feature. A pattern is observed between 'word_share' and 'is_duplicate'. As the value of word_share increases, the two questions are more likely to be a duplicate of each other.

# %%
sns.boxplot(x='is_duplicate',y='word_share', data=dataframe)
plt.show()

# %% [markdown]
# The boxplots are not extremely overlaping and useful information ca be extracted from this feature.

# %%
sns.violinplot(x="is_duplicate", y="word_share", data=dataframe, height=8)
plt.show()

# %% [markdown]
# Similar results can be obtained from the violin plot as well.

# %% [markdown]
# ### n_common_words

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g=sns.FacetGrid(dataframe, hue="is_duplicate", height=5)
g=g.map(sns.distplot, "n_common_words").add_legend();
g.axes[0,0].set_xlabel('n_common_words')
plt.title('n_common_words Histogram')
plt.show();

# %% [markdown]
# This plot is extremely overlapping and it is almost impossible to extract any useful information from this.
